# %% [markdown]
# # 06 Campaign Forecast
#
# Notebook interface for scenario forecasting from business campaign briefs. The source workflow is `02_Code/03_AC_forecast/ac_forecast.py`.

# %% [markdown]
# ## Status
#
# Thin launcher / run card for the compact code layout. Outputs should go to `03_Outputs/03_AC_forecast_outputs/NN_AC_forecast_DDMMYYYY[_label]/`.

# %%
# Example command; keep commented until running a forecast intentionally.
# %run ../../03_AC_forecast/ac_forecast.py --config ../../03_AC_forecast/ac_forecast_template.yaml
