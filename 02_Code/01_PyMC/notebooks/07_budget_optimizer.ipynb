# %% [markdown]
# # 07 Budget Optimizer
#
# Notebook interface for budget optimization scenarios. The source workflow is `02_Code/02_Budget_optimizer/budget_optimizer.py`.

# %% [markdown]
# ## Status
#
# Thin launcher / run card for the compact code layout. Outputs should go to `03_Outputs/02_Budget_optimizer_outputs/NN_Budget_optimizer_DDMMYYYY[_label]/`.

# %%
# Example command; keep commented until running optimization intentionally.
# %run ../../02_Budget_optimizer/budget_optimizer.py --config ../../02_Budget_optimizer/budget_optimizer_template.yaml
