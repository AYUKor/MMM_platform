# %% [markdown]
# # 05 Data Refresh 2026H1
#
# Notebook interface for the current compact data refresh workflow: raw inputs -> DQ/audit -> exact weather/macro controls -> model-ready panel. The executable source of truth is `00_Data/data_pipeline.py` plus `00_Data/data_pipeline_config.yaml`.

# %% [markdown]
# ## Status
#
# Use this notebook only as a thin launcher / run card. The current final v2 artifact is `00_Data/02_2025_2026Q1_second_pass/panel_final_v2.parquet`; model-side refits should consume that parquet instead of rebuilding data inside PyMC notebooks.

# %%
# Build the current v2 panel from the compact data pipeline.
# Keep the command commented until you intentionally want to rebuild panel_final_v2.parquet.
# %run ../../../00_Data/data_pipeline.py --config ../../../00_Data/data_pipeline_config.yaml --mode build_panel
